# %% [markdown]
# Airbnb 2020 Data

# %%
# Importing Data

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
path = r'C:\Users\13526\Documents\Airbnb Data Project'

# %%
df = pd.read_csv(r'C:\Users\13526\Documents\Airbnb Data Project\02 Data\airbnb_clean.csv', index_col = False)
# Out:
# C:\Users\13526\AppData\Local\Temp\ipykernel_26676\2315830310.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\13526\Documents\Airbnb Data Project\02 Data\airbnb_clean.csv', index_col = False)

# %%
df.head()
# Out:
#    Unnamed: 0      id                                               name  \
# 0           0   38585    Charming Victorian home - twin beds + breakfast
# 1           1   80905                                   French Chic Loft
# 2           2  108061  Walk to stores/parks/downtown. Fenced yard/Pet...
# 3           3  155305                 Cottage! BonPaul + Sharky's Hostel
# 4           4  160594                                Historic Grove Park
#
#    host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0   165529                 NaN         28804  35.65146  -82.62792
# 1   427027                 NaN         28801  35.59779  -82.55540
# 2   320564                 NaN         28801  35.60670  -82.55563
# 3   746673                 NaN         28806  35.57864  -82.59578
# 4   769252                 NaN         28801  35.61442  -82.54127
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (225967, 17)

# %%
df.describe().round()
# Out:
#        Unnamed: 0          id      host_id  latitude  longitude     price  \
# count    225967.0    225967.0     225967.0  225967.0   225967.0  225967.0
# mean     113014.0  25472820.0   93523787.0      36.0     -103.0     220.0
# std       65250.0  13177881.0   98273022.0       7.0       26.0     569.0
# min           0.0       109.0         23.0      19.0     -160.0       0.0
# 25%       56506.0  15159744.0   13993105.0      33.0     -119.0      75.0
# 50%      113013.0  25910521.0   51384446.0      37.0      -98.0     121.0
# 75%      169520.0  37727173.0  149711013.0      41.0      -77.0     201.0
# max      226029.0  45560850.0  367917574.0      48.0      -71.0   24999.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count        225967.0           225967.0           177380.0
# mean             10.0               35.0                1.0
# std              21.0               64.0                2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225967 entries, 0 to 225966
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      225967 non-null  int64
#  1   id                              225967 non-null  int64
#  2   name                            225940 non-null  object
#  3   host_id                         225967 non-null  int64
#  4   neighbourhood_group             110153 non-null  object
#  5   neighbourhood                   225967 non-null  object
#  6   latitude                        225967 non-null  float64
#  7   longitude                       225967 non-null  float64
#  8   room_type                       225967 non-null  object
#  9   price                           225967 non-null  int64
#  10  minimum_nights                  225967 non-null  int64
#  11  number_of_reviews               225967 non-null  int64
# ...

# %%
for col in df.columns.tolist():
    weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df[weird]) > 0:
        print (col)
# Out:
# name
# neighbourhood_group
# last_review

# %%
df['name'] = df['name'].astype('str')

# %%
df['neighbourhood_group'] = df['neighbourhood_group'].astype('str')

# %%
df['last_review'] = df['last_review'].astype('str')

# %%
for col in df.columns.tolist():
    weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df[weird]) > 0:
        print (col)

# %%
df.shape
# Out:
# (225967, 17)

# %%
df['price'] = df['price'].astype('int8')
df['id'] = df['id'].astype('int16')
df['host_id'] = df['host_id'].astype('int16')
df['minimum_nights'] = df['minimum_nights'].astype('int16')
df['number_of_reviews'] = df['number_of_reviews'].astype('int16')
df['calculated_host_listings_count'] = df['calculated_host_listings_count'].astype('int16')
df['availability_365'] = df['availability_365'].astype('int16')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                            0
# id                                    0
# name                                  0
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                           0
# reviews_per_month                 48587
# calculated_host_listings_count        0
# availability_365                      0
# city                                  0
# dtype: int64

# %%
df.shape
# Out:
# (225967, 17)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'host_id', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'city'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225967 entries, 0 to 225966
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      225967 non-null  int64
#  1   id                              225967 non-null  int16
#  2   name                            225967 non-null  object
#  3   host_id                         225967 non-null  int16
#  4   neighbourhood_group             225967 non-null  object
#  5   neighbourhood                   225967 non-null  object
#  6   latitude                        225967 non-null  float64
#  7   longitude                       225967 non-null  float64
#  8   room_type                       225967 non-null  object
#  9   price                           225967 non-null  int8
#  10  minimum_nights                  225967 non-null  int16
#  11  number_of_reviews               225967 non-null  int16
# ...

# %% [markdown]
# ## Exploring the Relationships

# %%
# Create a correlation matrix using pandas
df.corr()
# Out:
#                                 Unnamed: 0        id   host_id  latitude  \
# Unnamed: 0                        1.000000 -0.002855 -0.019405  0.522627
# id                               -0.002855  1.000000  0.000940 -0.012820
# host_id                          -0.019405  0.000940  1.000000 -0.029178
# latitude                          0.522627 -0.012820 -0.029178  1.000000
# longitude                         0.087423 -0.012798 -0.017967  0.579938
# price                             0.030261 -0.003408 -0.014686  0.081811
# minimum_nights                   -0.029142  0.002540 -0.001508  0.053855
# number_of_reviews                 0.003955  0.002527 -0.006276  0.047393
# reviews_per_month                 0.000009  0.001132  0.000958  0.053945
# calculated_host_listings_count   -0.098023  0.013034  0.081770 -0.182674
# availability_365                 -0.113859  0.003189  0.014729 -0.177671
#
#                                 longitude     price  minimum_nights  \
# ...

# %%
# Create a correlation heatmap using matplotlib
plt.matshow(df.corr())
plt.show()

# %%
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\13526\\Documents\\Airbnb Data Project\\02 Data'

# %%
# Add labels, a legend, and change the size of the heatmap
f = plt.figure(figsize=(8, 8)) # figure size
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
sns.lmplot(x = 'price', y = 'minimum_nights', data = df)

# %%
# Turning my objests into values to plot
result = []

for value in df["room_type"]:
    if value == 'Private room':
        result.append("1")
    elif value == 'Entire home/apt':
        result.append("2")
    elif value == 'Hotel room':
        result.append("3")
    elif value == 'Shared room':
        result.append("4")
    else:
        result.append("5")

# %%
result
# Out:
# ['1',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '1',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '1',
#  '1',
#  '2',
#  '1',
#  '1',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '1',
#  '1',
#  '1',
#  '1',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '3',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
# ...

# %%
df['room_type_by_number'] = result

# %%
df['room_type_by_number'].value_counts(dropna = False)
# Out:
# 2    154134
# 1     65864
# 4      4028
# 3      1941
# Name: room_type_by_number, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225967 entries, 0 to 225966
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      225967 non-null  int64
#  1   id                              225967 non-null  int16
#  2   name                            225967 non-null  object
#  3   host_id                         225967 non-null  int16
#  4   neighbourhood_group             225967 non-null  object
#  5   neighbourhood                   225967 non-null  object
#  6   latitude                        225967 non-null  float64
#  7   longitude                       225967 non-null  float64
#  8   room_type                       225967 non-null  object
#  9   price                           225967 non-null  int8
#  10  minimum_nights                  225967 non-null  int16
#  11  number_of_reviews               225967 non-null  int16
# ...

# %%
df['room_type_by_number'] = df['room_type_by_number'].astype('int8')

# %%
#checking my work
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225967 entries, 0 to 225966
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      225967 non-null  int64
#  1   id                              225967 non-null  int16
#  2   name                            225967 non-null  object
#  3   host_id                         225967 non-null  int16
#  4   neighbourhood_group             225967 non-null  object
#  5   neighbourhood                   225967 non-null  object
#  6   latitude                        225967 non-null  float64
#  7   longitude                       225967 non-null  float64
#  8   room_type                       225967 non-null  object
#  9   price                           225967 non-null  int8
#  10  minimum_nights                  225967 non-null  int16
#  11  number_of_reviews               225967 non-null  int16
# ...

# %%
sns.lmplot(y = 'minimum_nights', x = 'room_type_by_number', data = df)

# %%
pp = df[['price', 'minimum_nights', 'room_type_by_number']]

# %%
pp
# Out:
#         price  minimum_nights  room_type_by_number
# 0          60               1                    1
# 1         -42               1                    2
# 2          75              30                    2
# 3          90               1                    2
# 4         125              30                    1
# ...       ...             ...                  ...
# 225962    104               1                    2
# 225963   -105               2                    2
# 225964    -16               2                    2
# 225965     60              21                    2
# 225966     79               7                    2
#
# [225967 rows x 3 columns]

# %%
g = sns.pairplot(pp)

# %% [markdown]
# If a personal budget allows it, then a person would rather choose privacy than a shared space. And would also be willing to stay longer in those places.
